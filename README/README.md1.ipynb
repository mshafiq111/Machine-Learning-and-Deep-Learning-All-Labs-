# %% [markdown]
# # Machine Learning & Deep Learning Lab Reports
#
# ## Overview
#
# This repository contains the laboratory reports completed during the Machine Learning and Deep Learning course as part of the Bachelor of Science in Electrical Engineering program.
#
# The reports document the theoretical concepts, methodologies, experimental procedures, implementations, results, and observations obtained throughout the laboratory sessions.
#
# ---
#
# ## Laboratory Reports
#
# | Lab No. | Title                                         |
# | ------- | --------------------------------------------- |
# | Lab 02  | Introduction to Data Analysis Libraries       |
# | Lab 03  | Data Cleaning and Preprocessing               |
# | Lab 04  | Feature Engineering                           |
# | Lab 05  | Data Transformation Techniques                |
# | Lab 06  | Regression and Optimization                   |
# | Lab 07  | Image Dataset Preparation                     |
# | Lab 08  | Convolutional Neural Networks (CNN)           |
# | Lab 09  | Data Augmentation                             |
# | Lab 10  | Multi-Layer Perceptron (MLP)                  |
# | Lab 11  | One-Dimensional Convolutional Neural Networks |
# | Lab 12  | Long Short-Term Memory Networks (LSTM)        |
#
# ---
#
# ## Topics Covered
#
# * Data Analysis and Visualization
# * Data Preprocessing
# * Feature Engineering
# * Regression Techniques
# * Gradient Descent Optimization
# * Computer Vision Fundamentals
# * Convolutional Neural Networks
# * Data Augmentation
# * Multi-Layer Perceptrons
# * 1D CNN Architectures
# * Long Short-Term Memory Networks
# * Time-Series Forecasting
#
# ---
#
# ## Repository Structure
#
# ```text
# ML_and_DL_Lab_Reports/
# │
# ├── Lab_02_Report.pdf
# ├── Lab_03_Report.pdf
# ├── Lab_04_Report.pdf
# ├── Lab_05_Report.pdf
# ├── Lab_06_Report.pdf
# ├── Lab_07_Report.pdf
# ├── Lab_08_Report.pdf
# ├── Lab_09_Report.pdf
# ├── Lab_10_Report.pdf
# ├── Lab_11_Report.pdf
# ├── Lab_12_Report.pdf
# │
# └── README.md
# ```
#
# ---
#
# ## Purpose
#
# The purpose of this repository is to maintain a well-organized collection of Machine Learning and Deep Learning laboratory reports for academic documentation, learning, and reference.
#
# ---
#
# ## Author
#
# **Muhammad Shafiq**
# Bachelor of Science in Electrical Engineering
#
# ---
#
# ## Academic Use
#
# This repository is intended solely for educational and academic purposes.
